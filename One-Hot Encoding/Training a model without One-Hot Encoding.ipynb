# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
# Out:
# 2022-11-10 22:15:55.876845: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-10 22:15:55.962284: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-10 22:15:55.962319: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-10 22:15:55.983334: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-10 22:15:56.411922: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-10 22:15:56.412008: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-10 22:15:56.412014: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
dataset = load_iris()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['label'] = dataset.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
# Convert DataFrame into np array
X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
X = np.asarray(X)

# Convert DataFrame into np array
y = df[['label']]
y = np.asarray(y)

# %%
# Split the data set in a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.20,
  random_state=42
)

# %%
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________
# 2022-11-10 22:15:56.884126: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-11-10 22:15:56.884161: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-10 22:15:56.884174: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (fabio-XPS-15-7590): /proc/driver/nvidia/version does not exist
# 2022-11-10 22:15:56.884554: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 1s - loss: 0.7685 - accuracy: 0.6444 - val_loss: 1.0732 - val_accuracy: 0.6333 - 1s/epoch - 337ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 0.2417 - accuracy: 0.9556 - val_loss: 1.0626 - val_accuracy: 0.6333 - 28ms/epoch - 9ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.2141 - accuracy: 0.9222 - val_loss: 1.0451 - val_accuracy: 0.6333 - 31ms/epoch - 10ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.1157 - accuracy: 0.9667 - val_loss: 1.0221 - val_accuracy: 0.6000 - 23ms/epoch - 8ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.1012 - accuracy: 0.9667 - val_loss: 1.0082 - val_accuracy: 0.4667 - 26ms/epoch - 9ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.1106 - accuracy: 0.9667 - val_loss: 0.9954 - val_accuracy: 0.4333 - 24ms/epoch - 8ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.0798 - accuracy: 0.9778 - val_loss: 0.9817 - val_accuracy: 0.4333 - 25ms/epoch - 8ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 0.1239 - accuracy: 0.9778 - val_loss: 0.9682 - val_accuracy: 0.4000 - 24ms/epoch - 8ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.0402 - accuracy: 0.9889 - val_loss: 0.9563 - val_accuracy: 0.4000 - 25ms/epoch - 8ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.0614 - accuracy: 0.9889 - val_loss: 0.9487 - val_accuracy: 0.4000 - 25ms/epoch - 8ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.0551 - accuracy: 0.9889 - val_loss: 0.9399 - val_accuracy: 0.4000 - 22ms/epoch - 7ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.0476 - accuracy: 0.9889 - val_loss: 0.9299 - val_accuracy: 0.4000 - 25ms/epoch - 8ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.0523 - accuracy: 0.9889 - val_loss: 0.9210 - val_accuracy: 0.4000 - 24ms/epoch - 8ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.0311 - accuracy: 0.9889 - val_loss: 0.9116 - val_accuracy: 0.4000 - 25ms/epoch - 8ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.9004 - val_accuracy: 0.4000 - 22ms/epoch - 7ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.0451 - accuracy: 0.9889 - val_loss: 0.8868 - val_accuracy: 0.4000 - 27ms/epoch - 9ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.0650 - accuracy: 0.9667 - val_loss: 0.8737 - val_accuracy: 0.4000 - 25ms/epoch - 8ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.0615 - accuracy: 0.9667 - val_loss: 0.8572 - val_accuracy: 0.4333 - 24ms/epoch - 8ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.0331 - accuracy: 0.9889 - val_loss: 0.8417 - val_accuracy: 0.4333 - 24ms/epoch - 8ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.0437 - accuracy: 0.9889 - val_loss: 0.8329 - val_accuracy: 0.4667 - 24ms/epoch - 8ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.8284 - val_accuracy: 0.6000 - 25ms/epoch - 8ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.0673 - accuracy: 0.9667 - val_loss: 0.8278 - val_accuracy: 0.6333 - 23ms/epoch - 8ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.0580 - accuracy: 0.9667 - val_loss: 0.8236 - val_accuracy: 0.6333 - 26ms/epoch - 9ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.0565 - accuracy: 0.9889 - val_loss: 0.8113 - val_accuracy: 0.6333 - 23ms/epoch - 8ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.0339 - accuracy: 0.9889 - val_loss: 0.8043 - val_accuracy: 0.6333 - 26ms/epoch - 9ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.0444 - accuracy: 0.9778 - val_loss: 0.7988 - val_accuracy: 0.6000 - 23ms/epoch - 8ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.0438 - accuracy: 0.9889 - val_loss: 0.7877 - val_accuracy: 0.6000 - 26ms/epoch - 9ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.0608 - accuracy: 0.9778 - val_loss: 0.7758 - val_accuracy: 0.6333 - 23ms/epoch - 8ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.0864 - accuracy: 0.9556 - val_loss: 0.7638 - val_accuracy: 0.6667 - 26ms/epoch - 9ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.0981 - accuracy: 0.9778 - val_loss: 0.7457 - val_accuracy: 0.7333 - 28ms/epoch - 9ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.0397 - accuracy: 0.9889 - val_loss: 0.7086 - val_accuracy: 0.7333 - 24ms/epoch - 8ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.0307 - accuracy: 1.0000 - val_loss: 0.6759 - val_accuracy: 0.7333 - 24ms/epoch - 8ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.0487 - accuracy: 0.9778 - val_loss: 0.6576 - val_accuracy: 0.7000 - 24ms/epoch - 8ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.0324 - accuracy: 1.0000 - val_loss: 0.6468 - val_accuracy: 0.7000 - 24ms/epoch - 8ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.0729 - accuracy: 0.9889 - val_loss: 0.6354 - val_accuracy: 0.7333 - 24ms/epoch - 8ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.0367 - accuracy: 0.9889 - val_loss: 0.6230 - val_accuracy: 0.8000 - 26ms/epoch - 9ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.0620 - accuracy: 0.9778 - val_loss: 0.6069 - val_accuracy: 0.8000 - 27ms/epoch - 9ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.0315 - accuracy: 0.9889 - val_loss: 0.5847 - val_accuracy: 0.8000 - 24ms/epoch - 8ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.0692 - accuracy: 0.9778 - val_loss: 0.5605 - val_accuracy: 0.8333 - 29ms/epoch - 10ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.0403 - accuracy: 0.9889 - val_loss: 0.5402 - val_accuracy: 0.8333 - 26ms/epoch - 9ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.0309 - accuracy: 0.9889 - val_loss: 0.5220 - val_accuracy: 0.8333 - 23ms/epoch - 8ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.0421 - accuracy: 0.9778 - val_loss: 0.5078 - val_accuracy: 0.8333 - 24ms/epoch - 8ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.0389 - accuracy: 0.9889 - val_loss: 0.4972 - val_accuracy: 0.8000 - 24ms/epoch - 8ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.4951 - val_accuracy: 0.8000 - 27ms/epoch - 9ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.3795 - accuracy: 0.9333 - val_loss: 0.4893 - val_accuracy: 0.8333 - 24ms/epoch - 8ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.1346 - accuracy: 0.9333 - val_loss: 0.5006 - val_accuracy: 0.8667 - 25ms/epoch - 8ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.0421 - accuracy: 0.9889 - val_loss: 0.5158 - val_accuracy: 0.8667 - 26ms/epoch - 9ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.1089 - accuracy: 0.9889 - val_loss: 0.5181 - val_accuracy: 0.8333 - 24ms/epoch - 8ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.0500 - accuracy: 0.9778 - val_loss: 0.5102 - val_accuracy: 0.8667 - 27ms/epoch - 9ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.0548 - accuracy: 0.9889 - val_loss: 0.4975 - val_accuracy: 0.8667 - 27ms/epoch - 9ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.4848 - val_accuracy: 0.8667 - 25ms/epoch - 8ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.0912 - accuracy: 0.9667 - val_loss: 0.4745 - val_accuracy: 0.8333 - 25ms/epoch - 8ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.0360 - accuracy: 0.9889 - val_loss: 0.4682 - val_accuracy: 0.8333 - 29ms/epoch - 10ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.1627 - accuracy: 0.9444 - val_loss: 0.4653 - val_accuracy: 0.8333 - 25ms/epoch - 8ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.4822 - val_accuracy: 0.7667 - 24ms/epoch - 8ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.0501 - accuracy: 0.9889 - val_loss: 0.4791 - val_accuracy: 0.7667 - 24ms/epoch - 8ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.0655 - accuracy: 0.9778 - val_loss: 0.4653 - val_accuracy: 0.7667 - 25ms/epoch - 8ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.0630 - accuracy: 0.9667 - val_loss: 0.4574 - val_accuracy: 0.7333 - 26ms/epoch - 9ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.0317 - accuracy: 1.0000 - val_loss: 0.4485 - val_accuracy: 0.7667 - 24ms/epoch - 8ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.0342 - accuracy: 0.9889 - val_loss: 0.4376 - val_accuracy: 0.8000 - 27ms/epoch - 9ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.1309 - accuracy: 0.9778 - val_loss: 0.4223 - val_accuracy: 0.8000 - 23ms/epoch - 8ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.4031 - val_accuracy: 0.8333 - 24ms/epoch - 8ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.1078 - accuracy: 0.9667 - val_loss: 0.3849 - val_accuracy: 0.8667 - 23ms/epoch - 8ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.0365 - accuracy: 0.9889 - val_loss: 0.3744 - val_accuracy: 0.8667 - 26ms/epoch - 9ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.0795 - accuracy: 0.9667 - val_loss: 0.3617 - val_accuracy: 0.8667 - 24ms/epoch - 8ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.0546 - accuracy: 0.9667 - val_loss: 0.3594 - val_accuracy: 0.9000 - 23ms/epoch - 8ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.3511 - val_accuracy: 0.9000 - 23ms/epoch - 8ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.3338 - val_accuracy: 0.9333 - 25ms/epoch - 8ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.0699 - accuracy: 0.9889 - val_loss: 0.3250 - val_accuracy: 0.9333 - 28ms/epoch - 9ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.0464 - accuracy: 0.9778 - val_loss: 0.3402 - val_accuracy: 0.9000 - 22ms/epoch - 7ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.3418 - val_accuracy: 0.8667 - 23ms/epoch - 8ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.0283 - accuracy: 0.9889 - val_loss: 0.3360 - val_accuracy: 0.8667 - 23ms/epoch - 8ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.0469 - accuracy: 0.9667 - val_loss: 0.3403 - val_accuracy: 0.8667 - 24ms/epoch - 8ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.0318 - accuracy: 0.9889 - val_loss: 0.3715 - val_accuracy: 0.8333 - 24ms/epoch - 8ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.0543 - accuracy: 0.9778 - val_loss: 0.4097 - val_accuracy: 0.8000 - 25ms/epoch - 8ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.0716 - accuracy: 0.9778 - val_loss: 0.4256 - val_accuracy: 0.8000 - 24ms/epoch - 8ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.0544 - accuracy: 0.9667 - val_loss: 0.3641 - val_accuracy: 0.8333 - 24ms/epoch - 8ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.0325 - accuracy: 0.9778 - val_loss: 0.2732 - val_accuracy: 0.8667 - 22ms/epoch - 7ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.0232 - accuracy: 0.9889 - val_loss: 0.1933 - val_accuracy: 0.9333 - 22ms/epoch - 7ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.0266 - accuracy: 0.9889 - val_loss: 0.1447 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.0995 - accuracy: 0.9556 - val_loss: 0.1161 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.0562 - accuracy: 0.9778 - val_loss: 0.1629 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.1128 - accuracy: 0.9556 - val_loss: 0.1490 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.0531 - accuracy: 0.9667 - val_loss: 0.1215 - val_accuracy: 0.9667 - 26ms/epoch - 9ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.1080 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.1010 - accuracy: 0.9667 - val_loss: 0.0969 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.0988 - accuracy: 0.9889 - val_loss: 0.0995 - val_accuracy: 0.9667 - 22ms/epoch - 7ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.0390 - accuracy: 0.9778 - val_loss: 0.1150 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.0370 - accuracy: 0.9889 - val_loss: 0.1285 - val_accuracy: 0.9667 - 22ms/epoch - 7ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.0421 - accuracy: 0.9778 - val_loss: 0.1159 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.0543 - accuracy: 0.9778 - val_loss: 0.1081 - val_accuracy: 1.0000 - 27ms/epoch - 9ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.0546 - accuracy: 0.9778 - val_loss: 0.1028 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.0614 - accuracy: 0.9889 - val_loss: 0.0955 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9667 - 22ms/epoch - 7ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.1216 - accuracy: 0.9444 - val_loss: 0.0859 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.0549 - accuracy: 0.9889 - val_loss: 0.1004 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.0389 - accuracy: 0.9778 - val_loss: 0.1224 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.1674 - accuracy: 0.9333 - val_loss: 0.1282 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.0617 - accuracy: 0.9889 - val_loss: 0.1100 - val_accuracy: 0.9667 - 25ms/epoch - 8ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.0658 - accuracy: 0.9778 - val_loss: 0.1024 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.1174 - accuracy: 0.9444 - val_loss: 0.1023 - val_accuracy: 0.9667 - 28ms/epoch - 9ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.1078 - val_accuracy: 0.9667 - 25ms/epoch - 8ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.0514 - accuracy: 0.9889 - val_loss: 0.1055 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.0517 - accuracy: 0.9778 - val_loss: 0.0980 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0884 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.0384 - accuracy: 0.9889 - val_loss: 0.0805 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.0235 - accuracy: 0.9889 - val_loss: 0.0678 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.1358 - accuracy: 0.9667 - val_loss: 0.0624 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0574 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.0546 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.0358 - accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.0315 - accuracy: 0.9889 - val_loss: 0.0491 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.0854 - accuracy: 0.9889 - val_loss: 0.0493 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.0337 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9667 - 22ms/epoch - 7ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.1099 - accuracy: 0.9778 - val_loss: 0.0746 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.0607 - accuracy: 0.9778 - val_loss: 0.1223 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.1612 - val_accuracy: 0.9333 - 25ms/epoch - 8ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.0776 - accuracy: 0.9778 - val_loss: 0.1642 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9667 - 28ms/epoch - 9ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.0308 - accuracy: 0.9889 - val_loss: 0.1323 - val_accuracy: 0.9333 - 22ms/epoch - 7ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.0484 - accuracy: 0.9778 - val_loss: 0.1307 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9000 - 24ms/epoch - 8ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.0534 - accuracy: 0.9778 - val_loss: 0.1408 - val_accuracy: 0.9000 - 24ms/epoch - 8ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.1885 - val_accuracy: 0.9000 - 26ms/epoch - 9ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.2061 - accuracy: 0.9444 - val_loss: 0.2064 - val_accuracy: 0.9000 - 24ms/epoch - 8ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9000 - 23ms/epoch - 8ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9000 - 25ms/epoch - 8ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.0378 - accuracy: 0.9889 - val_loss: 0.1086 - val_accuracy: 0.9000 - 24ms/epoch - 8ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.0566 - accuracy: 0.9778 - val_loss: 0.0989 - val_accuracy: 0.9667 - 27ms/epoch - 9ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.0582 - accuracy: 0.9889 - val_loss: 0.0889 - val_accuracy: 0.9667 - 25ms/epoch - 8ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.0366 - accuracy: 0.9889 - val_loss: 0.1043 - val_accuracy: 0.9333 - 26ms/epoch - 9ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.0577 - accuracy: 0.9778 - val_loss: 0.1525 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.0604 - accuracy: 0.9667 - val_loss: 0.2591 - val_accuracy: 0.9333 - 25ms/epoch - 8ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.0731 - accuracy: 0.9667 - val_loss: 0.3296 - val_accuracy: 0.9000 - 24ms/epoch - 8ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.0983 - accuracy: 0.9667 - val_loss: 0.2172 - val_accuracy: 0.9000 - 23ms/epoch - 8ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.0246 - accuracy: 0.9889 - val_loss: 0.1529 - val_accuracy: 0.9333 - 25ms/epoch - 8ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.0238 - accuracy: 0.9889 - val_loss: 0.1654 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.0457 - accuracy: 0.9778 - val_loss: 0.1671 - val_accuracy: 0.9000 - 23ms/epoch - 8ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.0695 - accuracy: 0.9889 - val_loss: 0.1561 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.0299 - accuracy: 0.9889 - val_loss: 0.1460 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.0381 - accuracy: 0.9778 - val_loss: 0.1470 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.0746 - accuracy: 0.9778 - val_loss: 0.1548 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.0264 - accuracy: 0.9889 - val_loss: 0.1854 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9000 - 26ms/epoch - 9ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.2706 - accuracy: 0.9333 - val_loss: 0.2692 - val_accuracy: 0.8667 - 23ms/epoch - 8ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9000 - 23ms/epoch - 8ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.0598 - accuracy: 0.9889 - val_loss: 0.1599 - val_accuracy: 0.9000 - 24ms/epoch - 8ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9000 - 25ms/epoch - 8ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.0393 - accuracy: 0.9889 - val_loss: 0.1838 - val_accuracy: 0.9000 - 23ms/epoch - 8ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.0393 - accuracy: 0.9778 - val_loss: 0.1619 - val_accuracy: 0.9000 - 23ms/epoch - 8ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.1093 - accuracy: 0.9778 - val_loss: 0.1283 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.1964 - accuracy: 0.9778 - val_loss: 0.1088 - val_accuracy: 0.9667 - 26ms/epoch - 9ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.0479 - accuracy: 0.9889 - val_loss: 0.1301 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9333 - 26ms/epoch - 9ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.0372 - accuracy: 0.9889 - val_loss: 0.1365 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.1304 - accuracy: 0.9778 - val_loss: 0.1162 - val_accuracy: 0.9333 - 27ms/epoch - 9ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.0693 - accuracy: 0.9778 - val_loss: 0.0792 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.0594 - accuracy: 0.9889 - val_loss: 0.0636 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.0778 - accuracy: 0.9889 - val_loss: 0.0734 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.0669 - accuracy: 0.9778 - val_loss: 0.1539 - val_accuracy: 0.9333 - 26ms/epoch - 9ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.0393 - accuracy: 0.9889 - val_loss: 0.1843 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.0285 - accuracy: 0.9889 - val_loss: 0.1932 - val_accuracy: 0.9333 - 27ms/epoch - 9ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.1734 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.0450 - accuracy: 0.9778 - val_loss: 0.1355 - val_accuracy: 0.9333 - 26ms/epoch - 9ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9667 - 25ms/epoch - 8ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.0254 - accuracy: 0.9889 - val_loss: 0.0679 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.0360 - accuracy: 0.9889 - val_loss: 0.0552 - val_accuracy: 0.9667 - 22ms/epoch - 7ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.0398 - accuracy: 0.9778 - val_loss: 0.0531 - val_accuracy: 0.9667 - 28ms/epoch - 9ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.0285 - accuracy: 0.9889 - val_loss: 0.0482 - val_accuracy: 0.9667 - 22ms/epoch - 7ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0517 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.0433 - accuracy: 0.9778 - val_loss: 0.0684 - val_accuracy: 0.9667 - 24ms/epoch - 8ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.0600 - accuracy: 0.9778 - val_loss: 0.2057 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.3476 - val_accuracy: 0.8667 - 24ms/epoch - 8ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.1886 - accuracy: 0.9667 - val_loss: 0.4532 - val_accuracy: 0.8333 - 22ms/epoch - 7ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.4190 - val_accuracy: 0.8333 - 25ms/epoch - 8ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.3484 - val_accuracy: 0.8667 - 24ms/epoch - 8ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.2618 - val_accuracy: 0.8667 - 24ms/epoch - 8ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9333 - 24ms/epoch - 8ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.1749 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9333 - 23ms/epoch - 8ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0265 - accuracy: 0.9889 - val_loss: 0.1516 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0386 - accuracy: 0.9889 - val_loss: 0.1374 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.0430 - accuracy: 0.9889 - val_loss: 0.1310 - val_accuracy: 0.9667 - 29ms/epoch - 10ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0374 - accuracy: 0.9889 - val_loss: 0.1239 - val_accuracy: 0.9667 - 25ms/epoch - 8ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.0603 - accuracy: 0.9778 - val_loss: 0.1073 - val_accuracy: 0.9667 - 23ms/epoch - 8ms/step

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_' + metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation ' + metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_' + metric])
    plt.show()

# %%
plot_metric(history, 'accuracy')

# %%
plot_metric(history, 'loss')

# %%
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.1364 - accuracy: 0.9333 - 16ms/epoch - 16ms/step
# [0.13642512261867523, 0.9333333373069763]

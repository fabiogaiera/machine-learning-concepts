# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization

# %%
# Load data into a DataFrame
dataset = load_iris()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)

# Append "target" and name it "label"
df['label'] = dataset.target

# Use string label instead
df['label'] = df.label.replace(dict(enumerate(dataset.target_names)))

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#     label
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Transform label to one-hot encoding
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)

# Drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label_setosa  label_versicolor  label_virginica
# 0             1                 0                0
# 1             1                 0                0
# 2             1                 0                0
# 3             1                 0                0
# 4             1                 0                0

# %%
# Creating X and y

# Convert DataFrame into np array
X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
X = np.asarray(X)

# Convert DataFrame into np array
y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
y = np.asarray(y)

# %%
# Split the data set in a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.20,
  random_state=42
)

# %%
# Model with batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 1s - loss: 1.1672 - accuracy: 0.5000 - val_loss: 1.0862 - val_accuracy: 0.3667 - 1s/epoch - 461ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 0.2616 - accuracy: 0.9444 - val_loss: 1.0612 - val_accuracy: 0.7000 - 33ms/epoch - 11ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.1452 - accuracy: 0.9778 - val_loss: 1.0402 - val_accuracy: 0.5000 - 32ms/epoch - 11ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.1291 - accuracy: 0.9556 - val_loss: 1.0199 - val_accuracy: 0.4000 - 34ms/epoch - 11ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.1246 - accuracy: 0.9667 - val_loss: 0.9988 - val_accuracy: 0.4000 - 33ms/epoch - 11ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.1047 - accuracy: 0.9667 - val_loss: 0.9846 - val_accuracy: 0.4000 - 35ms/epoch - 12ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.0798 - accuracy: 0.9778 - val_loss: 0.9758 - val_accuracy: 0.4000 - 34ms/epoch - 11ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 0.0886 - accuracy: 0.9778 - val_loss: 0.9691 - val_accuracy: 0.4000 - 33ms/epoch - 11ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.1268 - accuracy: 0.9667 - val_loss: 0.9644 - val_accuracy: 0.4000 - 35ms/epoch - 12ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.0511 - accuracy: 0.9889 - val_loss: 0.9595 - val_accuracy: 0.4000 - 37ms/epoch - 12ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.1181 - accuracy: 0.9667 - val_loss: 0.9521 - val_accuracy: 0.4000 - 33ms/epoch - 11ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.0653 - accuracy: 0.9778 - val_loss: 0.9413 - val_accuracy: 0.4000 - 34ms/epoch - 11ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.1093 - accuracy: 0.9667 - val_loss: 0.9258 - val_accuracy: 0.4000 - 34ms/epoch - 11ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.0542 - accuracy: 1.0000 - val_loss: 0.9033 - val_accuracy: 0.4000 - 34ms/epoch - 11ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.1022 - accuracy: 0.9444 - val_loss: 0.8887 - val_accuracy: 0.4000 - 35ms/epoch - 12ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.0923 - accuracy: 0.9778 - val_loss: 0.8779 - val_accuracy: 0.4000 - 33ms/epoch - 11ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.0709 - accuracy: 0.9889 - val_loss: 0.8820 - val_accuracy: 0.4000 - 33ms/epoch - 11ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.0682 - accuracy: 0.9778 - val_loss: 0.8847 - val_accuracy: 0.4333 - 33ms/epoch - 11ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.1006 - accuracy: 0.9667 - val_loss: 0.8766 - val_accuracy: 0.4667 - 34ms/epoch - 11ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.0737 - accuracy: 0.9667 - val_loss: 0.8637 - val_accuracy: 0.5000 - 33ms/epoch - 11ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.0757 - accuracy: 0.9667 - val_loss: 0.8373 - val_accuracy: 0.5333 - 34ms/epoch - 11ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.0477 - accuracy: 0.9889 - val_loss: 0.7960 - val_accuracy: 0.5333 - 34ms/epoch - 11ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.0380 - accuracy: 1.0000 - val_loss: 0.7563 - val_accuracy: 0.5667 - 35ms/epoch - 12ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.0657 - accuracy: 0.9778 - val_loss: 0.7379 - val_accuracy: 0.5667 - 32ms/epoch - 11ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.0670 - accuracy: 0.9778 - val_loss: 0.7248 - val_accuracy: 0.5667 - 34ms/epoch - 11ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.0576 - accuracy: 0.9778 - val_loss: 0.7144 - val_accuracy: 0.5667 - 33ms/epoch - 11ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.0676 - accuracy: 0.9667 - val_loss: 0.7108 - val_accuracy: 0.5667 - 42ms/epoch - 14ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.0661 - accuracy: 0.9667 - val_loss: 0.7256 - val_accuracy: 0.5667 - 33ms/epoch - 11ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.0615 - accuracy: 0.9778 - val_loss: 0.7449 - val_accuracy: 0.5667 - 32ms/epoch - 11ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.0935 - accuracy: 0.9556 - val_loss: 0.7511 - val_accuracy: 0.5667 - 32ms/epoch - 11ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.0651 - accuracy: 0.9667 - val_loss: 0.7495 - val_accuracy: 0.5667 - 30ms/epoch - 10ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.0645 - accuracy: 0.9667 - val_loss: 0.7392 - val_accuracy: 0.5667 - 35ms/epoch - 12ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.0408 - accuracy: 0.9889 - val_loss: 0.7235 - val_accuracy: 0.5667 - 33ms/epoch - 11ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.0736 - accuracy: 0.9778 - val_loss: 0.7167 - val_accuracy: 0.5667 - 31ms/epoch - 10ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.0472 - accuracy: 0.9778 - val_loss: 0.7252 - val_accuracy: 0.6667 - 32ms/epoch - 11ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.0746 - accuracy: 0.9889 - val_loss: 0.7328 - val_accuracy: 0.6667 - 34ms/epoch - 11ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.0469 - accuracy: 0.9889 - val_loss: 0.7428 - val_accuracy: 0.7000 - 34ms/epoch - 11ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.0758 - accuracy: 0.9889 - val_loss: 0.7528 - val_accuracy: 0.7000 - 34ms/epoch - 11ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.0558 - accuracy: 0.9667 - val_loss: 0.7552 - val_accuracy: 0.6667 - 36ms/epoch - 12ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.0731 - accuracy: 0.9778 - val_loss: 0.7483 - val_accuracy: 0.7000 - 34ms/epoch - 11ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.1326 - accuracy: 0.9667 - val_loss: 0.7092 - val_accuracy: 0.7333 - 34ms/epoch - 11ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.1470 - accuracy: 0.9667 - val_loss: 0.6049 - val_accuracy: 0.7667 - 32ms/epoch - 11ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.0648 - accuracy: 0.9667 - val_loss: 0.5233 - val_accuracy: 0.9000 - 31ms/epoch - 10ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.1032 - accuracy: 0.9667 - val_loss: 0.4752 - val_accuracy: 0.9667 - 34ms/epoch - 11ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.4510 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.0560 - accuracy: 0.9889 - val_loss: 0.4406 - val_accuracy: 0.8667 - 32ms/epoch - 11ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.0767 - accuracy: 0.9778 - val_loss: 0.4312 - val_accuracy: 0.8667 - 37ms/epoch - 12ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.4086 - val_accuracy: 0.9000 - 34ms/epoch - 11ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.0347 - accuracy: 0.9889 - val_loss: 0.3880 - val_accuracy: 0.9000 - 32ms/epoch - 11ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.0531 - accuracy: 0.9778 - val_loss: 0.3712 - val_accuracy: 0.9333 - 33ms/epoch - 11ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.3456 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.0311 - accuracy: 0.9889 - val_loss: 0.3254 - val_accuracy: 0.9333 - 32ms/epoch - 11ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.0612 - accuracy: 0.9778 - val_loss: 0.3152 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.0745 - accuracy: 0.9889 - val_loss: 0.3034 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.0410 - accuracy: 0.9889 - val_loss: 0.3014 - val_accuracy: 0.9333 - 32ms/epoch - 11ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.0529 - accuracy: 0.9667 - val_loss: 0.3404 - val_accuracy: 0.8667 - 32ms/epoch - 11ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.0497 - accuracy: 0.9778 - val_loss: 0.3774 - val_accuracy: 0.8333 - 39ms/epoch - 13ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.0423 - accuracy: 0.9778 - val_loss: 0.3880 - val_accuracy: 0.8000 - 31ms/epoch - 10ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.0772 - accuracy: 0.9778 - val_loss: 0.3731 - val_accuracy: 0.8333 - 33ms/epoch - 11ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.0765 - accuracy: 0.9667 - val_loss: 0.3429 - val_accuracy: 0.8333 - 31ms/epoch - 10ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.0560 - accuracy: 0.9778 - val_loss: 0.3058 - val_accuracy: 0.8667 - 32ms/epoch - 11ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.0400 - accuracy: 0.9889 - val_loss: 0.2736 - val_accuracy: 0.9000 - 31ms/epoch - 10ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.0413 - accuracy: 0.9778 - val_loss: 0.2465 - val_accuracy: 0.9000 - 32ms/epoch - 11ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.0436 - accuracy: 0.9778 - val_loss: 0.2272 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.0378 - accuracy: 0.9889 - val_loss: 0.2154 - val_accuracy: 0.9333 - 34ms/epoch - 11ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.0287 - accuracy: 0.9889 - val_loss: 0.2097 - val_accuracy: 0.9333 - 34ms/epoch - 11ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.0319 - accuracy: 0.9889 - val_loss: 0.2079 - val_accuracy: 0.9333 - 32ms/epoch - 11ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.0630 - accuracy: 0.9778 - val_loss: 0.2035 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.0374 - accuracy: 0.9778 - val_loss: 0.2036 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.0212 - accuracy: 0.9889 - val_loss: 0.2056 - val_accuracy: 0.9000 - 31ms/epoch - 10ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.0419 - accuracy: 0.9778 - val_loss: 0.1940 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.0957 - accuracy: 0.9556 - val_loss: 0.1820 - val_accuracy: 0.9333 - 32ms/epoch - 11ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.1814 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.0386 - accuracy: 0.9889 - val_loss: 0.1725 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.0456 - accuracy: 0.9778 - val_loss: 0.1468 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.0402 - accuracy: 0.9889 - val_loss: 0.1593 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.1519 - accuracy: 0.9444 - val_loss: 0.1811 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.0645 - accuracy: 0.9778 - val_loss: 0.2389 - val_accuracy: 0.9333 - 29ms/epoch - 10ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.1123 - accuracy: 0.9667 - val_loss: 0.2514 - val_accuracy: 0.8667 - 30ms/epoch - 10ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.0630 - accuracy: 0.9889 - val_loss: 0.2721 - val_accuracy: 0.8667 - 35ms/epoch - 12ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.3673 - accuracy: 0.9222 - val_loss: 0.2147 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.0482 - accuracy: 0.9889 - val_loss: 0.1607 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.0514 - accuracy: 0.9889 - val_loss: 0.1577 - val_accuracy: 1.0000 - 30ms/epoch - 10ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.0408 - accuracy: 0.9889 - val_loss: 0.1646 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.0883 - accuracy: 0.9667 - val_loss: 0.1621 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.0445 - accuracy: 0.9889 - val_loss: 0.1426 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.0389 - accuracy: 0.9889 - val_loss: 0.1208 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.0915 - accuracy: 0.9556 - val_loss: 0.1089 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.0310 - accuracy: 0.9889 - val_loss: 0.1036 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.0414 - accuracy: 0.9889 - val_loss: 0.1038 - val_accuracy: 1.0000 - 30ms/epoch - 10ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.0372 - accuracy: 0.9778 - val_loss: 0.0915 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0856 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.0204 - accuracy: 0.9889 - val_loss: 0.0855 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.0355 - accuracy: 0.9889 - val_loss: 0.0904 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.0191 - accuracy: 0.9889 - val_loss: 0.0897 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.0654 - accuracy: 0.9889 - val_loss: 0.0866 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.0462 - accuracy: 0.9889 - val_loss: 0.0846 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.0536 - accuracy: 0.9556 - val_loss: 0.0717 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.0307 - accuracy: 0.9889 - val_loss: 0.0567 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.0944 - accuracy: 0.9778 - val_loss: 0.0627 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.0729 - accuracy: 0.9889 - val_loss: 0.1134 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.0250 - accuracy: 0.9889 - val_loss: 0.1826 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.0458 - accuracy: 0.9889 - val_loss: 0.2036 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.0288 - accuracy: 0.9889 - val_loss: 0.1593 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.0614 - accuracy: 0.9889 - val_loss: 0.1347 - val_accuracy: 0.9667 - 34ms/epoch - 11ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.0473 - accuracy: 0.9889 - val_loss: 0.1144 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.0264 - accuracy: 0.9889 - val_loss: 0.0981 - val_accuracy: 0.9667 - 29ms/epoch - 10ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.0332 - accuracy: 0.9889 - val_loss: 0.0760 - val_accuracy: 1.0000 - 33ms/epoch - 11ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.1156 - accuracy: 0.9778 - val_loss: 0.0553 - val_accuracy: 1.0000 - 30ms/epoch - 10ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.0814 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9333 - 32ms/epoch - 11ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.0398 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9333 - 35ms/epoch - 12ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.0468 - accuracy: 0.9889 - val_loss: 0.1446 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.0367 - accuracy: 0.9889 - val_loss: 0.1238 - val_accuracy: 0.9333 - 32ms/epoch - 11ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.0445 - accuracy: 0.9778 - val_loss: 0.0965 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.0507 - accuracy: 0.9889 - val_loss: 0.0893 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.0315 - accuracy: 0.9889 - val_loss: 0.1166 - val_accuracy: 0.9333 - 32ms/epoch - 11ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.0371 - accuracy: 0.9889 - val_loss: 0.1127 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.0347 - accuracy: 0.9889 - val_loss: 0.0930 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.0331 - accuracy: 0.9778 - val_loss: 0.0350 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.0352 - accuracy: 0.9889 - val_loss: 0.0142 - val_accuracy: 1.0000 - 109ms/epoch - 36ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.0232 - accuracy: 0.9889 - val_loss: 0.0107 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.0668 - accuracy: 0.9778 - val_loss: 0.0105 - val_accuracy: 1.0000 - 30ms/epoch - 10ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.0586 - accuracy: 0.9778 - val_loss: 0.0225 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.0656 - accuracy: 0.9778 - val_loss: 0.0590 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.1289 - accuracy: 0.9667 - val_loss: 0.0860 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.1196 - accuracy: 0.9556 - val_loss: 0.0923 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.0375 - accuracy: 0.9889 - val_loss: 0.1173 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.0781 - accuracy: 0.9778 - val_loss: 0.1366 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.0632 - accuracy: 0.9667 - val_loss: 0.1282 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.0425 - accuracy: 0.9889 - val_loss: 0.1180 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.0461 - accuracy: 0.9889 - val_loss: 0.1335 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.0329 - accuracy: 0.9889 - val_loss: 0.1911 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.2203 - val_accuracy: 0.9333 - 34ms/epoch - 11ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.0323 - accuracy: 0.9889 - val_loss: 0.2254 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.0517 - accuracy: 0.9889 - val_loss: 0.2120 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.0377 - accuracy: 0.9778 - val_loss: 0.2121 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9333 - 29ms/epoch - 10ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.0193 - accuracy: 0.9889 - val_loss: 0.2266 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.1540 - accuracy: 0.9778 - val_loss: 0.1918 - val_accuracy: 0.9333 - 29ms/epoch - 10ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.0438 - accuracy: 0.9778 - val_loss: 0.1503 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.0310 - accuracy: 0.9889 - val_loss: 0.1414 - val_accuracy: 0.9333 - 28ms/epoch - 9ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.0635 - accuracy: 0.9556 - val_loss: 0.1099 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.0894 - accuracy: 0.9778 - val_loss: 0.0559 - val_accuracy: 1.0000 - 30ms/epoch - 10ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.0438 - accuracy: 0.9889 - val_loss: 0.0452 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.0746 - accuracy: 0.9667 - val_loss: 0.0433 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.1015 - accuracy: 0.9556 - val_loss: 0.0337 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.0419 - accuracy: 0.9889 - val_loss: 0.0450 - val_accuracy: 1.0000 - 31ms/epoch - 10ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.0629 - accuracy: 0.9667 - val_loss: 0.0766 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.0472 - accuracy: 0.9889 - val_loss: 0.0834 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.0386 - accuracy: 0.9889 - val_loss: 0.0959 - val_accuracy: 0.9333 - 33ms/epoch - 11ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.0292 - accuracy: 0.9778 - val_loss: 0.0998 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.0509 - accuracy: 0.9778 - val_loss: 0.1074 - val_accuracy: 0.9333 - 32ms/epoch - 11ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.0208 - accuracy: 0.9889 - val_loss: 0.1494 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.1745 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9667 - 33ms/epoch - 11ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.1362 - accuracy: 0.9444 - val_loss: 0.1850 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9333 - 30ms/epoch - 10ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.0480 - accuracy: 0.9778 - val_loss: 0.1375 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.0411 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9333 - 33ms/epoch - 11ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9000 - 31ms/epoch - 10ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.0493 - accuracy: 0.9778 - val_loss: 0.1305 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.0459 - accuracy: 0.9889 - val_loss: 0.1883 - val_accuracy: 0.8667 - 34ms/epoch - 11ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.1741 - accuracy: 0.9556 - val_loss: 0.2752 - val_accuracy: 0.8667 - 31ms/epoch - 10ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.0840 - accuracy: 0.9778 - val_loss: 0.2897 - val_accuracy: 0.8667 - 31ms/epoch - 10ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.0333 - accuracy: 1.0000 - val_loss: 0.2727 - val_accuracy: 0.9000 - 33ms/epoch - 11ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.0557 - accuracy: 0.9667 - val_loss: 0.2110 - val_accuracy: 0.9333 - 31ms/epoch - 10ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.0418 - accuracy: 0.9889 - val_loss: 0.1872 - val_accuracy: 0.9000 - 31ms/epoch - 10ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.0467 - accuracy: 0.9778 - val_loss: 0.1755 - val_accuracy: 0.9000 - 31ms/epoch - 10ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.2584 - accuracy: 0.9222 - val_loss: 0.0818 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.0787 - accuracy: 0.9889 - val_loss: 0.1233 - val_accuracy: 0.9667 - 32ms/epoch - 11ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.1071 - accuracy: 0.9778 - val_loss: 0.1511 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.1707 - accuracy: 0.9556 - val_loss: 0.1762 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.0575 - accuracy: 0.9889 - val_loss: 0.1624 - val_accuracy: 0.9667 - 30ms/epoch - 10ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.0849 - accuracy: 0.9667 - val_loss: 0.1367 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.0703 - accuracy: 0.9556 - val_loss: 0.1104 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0633 - accuracy: 0.9667 - val_loss: 0.0954 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.1008 - accuracy: 0.9667 - val_loss: 0.0982 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0252 - accuracy: 0.9889 - val_loss: 0.1059 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0383 - accuracy: 0.9889 - val_loss: 0.1168 - val_accuracy: 0.9667 - 31ms/epoch - 10ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.1173 - accuracy: 0.9556 - val_loss: 0.1364 - val_accuracy: 0.9667 - 29ms/epoch - 10ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0542 - accuracy: 0.9778 - val_loss: 0.1684 - val_accuracy: 0.9333 - 29ms/epoch - 10ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.0555 - accuracy: 0.9778 - val_loss: 0.1997 - val_accuracy: 0.9333 - 33ms/epoch - 11ms/step

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_' + metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation ' + metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_' + metric])
    plt.show()

# %%
plot_metric(history, 'accuracy')

# %%
plot_metric(history, 'loss')

# %%
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.0687 - accuracy: 0.9667 - 20ms/epoch - 20ms/step
# [0.06870096176862717, 0.9666666388511658]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization

# %%
# Load data into a DataFrame
dataset = load_iris()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)

# Append "target" and name it "label"
df['label'] = dataset.target

# Use string label instead
df['label'] = df.label.replace(dict(enumerate(dataset.target_names)))

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#     label
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Transform label to one-hot encoding
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)

# Drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label_setosa  label_versicolor  label_virginica
# 0             1                 0                0
# 1             1                 0                0
# 2             1                 0                0
# 3             1                 0                0
# 4             1                 0                0

# %%
# Creating X and y

# Convert DataFrame into np array
X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
X = np.asarray(X)

# Convert DataFrame into np array
y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
y = np.asarray(y)

# %%
# Split the data set in a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.20
)

# %%
# Model with batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 1s - loss: 0.6975 - accuracy: 0.7556 - val_loss: 1.0149 - val_accuracy: 0.3333 - 1s/epoch - 488ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 0.1515 - accuracy: 0.9778 - val_loss: 1.0177 - val_accuracy: 0.3333 - 37ms/epoch - 12ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.0857 - accuracy: 0.9667 - val_loss: 1.0231 - val_accuracy: 0.3333 - 36ms/epoch - 12ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.1222 - accuracy: 0.9778 - val_loss: 1.0361 - val_accuracy: 0.3333 - 36ms/epoch - 12ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.1412 - accuracy: 0.9778 - val_loss: 1.0529 - val_accuracy: 0.3333 - 37ms/epoch - 12ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.0770 - accuracy: 0.9778 - val_loss: 1.0665 - val_accuracy: 0.3333 - 35ms/epoch - 12ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.0490 - accuracy: 1.0000 - val_loss: 1.0732 - val_accuracy: 0.3333 - 45ms/epoch - 15ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 0.1466 - accuracy: 0.9556 - val_loss: 1.0783 - val_accuracy: 0.3333 - 37ms/epoch - 12ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.0505 - accuracy: 1.0000 - val_loss: 1.0844 - val_accuracy: 0.3333 - 39ms/epoch - 13ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.0556 - accuracy: 0.9889 - val_loss: 1.0925 - val_accuracy: 0.3333 - 40ms/epoch - 13ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.0674 - accuracy: 0.9889 - val_loss: 1.1038 - val_accuracy: 0.3333 - 41ms/epoch - 14ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.0574 - accuracy: 0.9778 - val_loss: 1.1057 - val_accuracy: 0.3333 - 44ms/epoch - 15ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.0630 - accuracy: 0.9667 - val_loss: 1.0778 - val_accuracy: 0.3333 - 37ms/epoch - 12ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.0334 - accuracy: 1.0000 - val_loss: 1.0509 - val_accuracy: 0.3333 - 40ms/epoch - 13ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.1941 - accuracy: 0.9333 - val_loss: 1.0431 - val_accuracy: 0.3333 - 38ms/epoch - 13ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.0389 - accuracy: 0.9889 - val_loss: 1.0542 - val_accuracy: 0.3333 - 39ms/epoch - 13ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.0604 - accuracy: 0.9889 - val_loss: 1.0632 - val_accuracy: 0.3333 - 39ms/epoch - 13ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.0434 - accuracy: 0.9889 - val_loss: 1.0680 - val_accuracy: 0.3333 - 36ms/epoch - 12ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.0474 - accuracy: 0.9889 - val_loss: 1.0697 - val_accuracy: 0.3333 - 42ms/epoch - 14ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.0683 - accuracy: 0.9778 - val_loss: 1.0705 - val_accuracy: 0.3333 - 37ms/epoch - 12ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.0320 - accuracy: 1.0000 - val_loss: 1.0709 - val_accuracy: 0.3333 - 37ms/epoch - 12ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.0283 - accuracy: 1.0000 - val_loss: 1.0700 - val_accuracy: 0.3333 - 45ms/epoch - 15ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.0216 - accuracy: 1.0000 - val_loss: 1.0649 - val_accuracy: 0.3333 - 48ms/epoch - 16ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.0671 - accuracy: 0.9889 - val_loss: 1.0533 - val_accuracy: 0.3333 - 37ms/epoch - 12ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.0433 - accuracy: 0.9889 - val_loss: 1.0366 - val_accuracy: 0.3333 - 42ms/epoch - 14ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.0616 - accuracy: 0.9778 - val_loss: 1.0114 - val_accuracy: 0.3333 - 36ms/epoch - 12ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.0294 - accuracy: 0.9889 - val_loss: 0.9686 - val_accuracy: 0.3333 - 35ms/epoch - 12ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.0557 - accuracy: 0.9778 - val_loss: 0.9460 - val_accuracy: 0.3333 - 37ms/epoch - 12ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.9460 - val_accuracy: 0.3333 - 44ms/epoch - 15ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.0444 - accuracy: 0.9778 - val_loss: 0.9434 - val_accuracy: 0.3333 - 43ms/epoch - 14ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.0258 - accuracy: 0.9889 - val_loss: 0.9363 - val_accuracy: 0.3667 - 38ms/epoch - 13ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.0620 - accuracy: 0.9667 - val_loss: 0.9308 - val_accuracy: 0.4000 - 34ms/epoch - 11ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.9362 - val_accuracy: 0.3667 - 38ms/epoch - 13ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.0577 - accuracy: 0.9667 - val_loss: 0.9359 - val_accuracy: 0.3667 - 37ms/epoch - 12ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.0286 - accuracy: 0.9889 - val_loss: 0.9359 - val_accuracy: 0.3333 - 36ms/epoch - 12ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.9299 - val_accuracy: 0.4000 - 40ms/epoch - 13ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.0227 - accuracy: 0.9889 - val_loss: 0.9132 - val_accuracy: 0.4000 - 38ms/epoch - 13ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.0557 - accuracy: 0.9778 - val_loss: 0.8746 - val_accuracy: 0.4667 - 38ms/epoch - 13ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.8597 - val_accuracy: 0.4667 - 39ms/epoch - 13ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.8459 - val_accuracy: 0.4667 - 41ms/epoch - 14ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.0450 - accuracy: 0.9889 - val_loss: 0.8310 - val_accuracy: 0.4333 - 40ms/epoch - 13ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.0802 - accuracy: 0.9667 - val_loss: 0.7953 - val_accuracy: 0.4667 - 48ms/epoch - 16ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.7211 - val_accuracy: 0.6000 - 41ms/epoch - 14ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.6627 - val_accuracy: 0.6333 - 35ms/epoch - 12ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.6168 - val_accuracy: 0.7000 - 40ms/epoch - 13ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.5806 - val_accuracy: 0.7333 - 37ms/epoch - 12ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.5557 - val_accuracy: 0.8000 - 44ms/epoch - 15ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.5301 - val_accuracy: 0.8667 - 37ms/epoch - 12ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.5013 - val_accuracy: 0.9000 - 38ms/epoch - 13ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.4434 - val_accuracy: 0.9667 - 36ms/epoch - 12ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.1288 - accuracy: 0.9556 - val_loss: 0.4124 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.3811 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.0309 - accuracy: 0.9889 - val_loss: 0.3796 - val_accuracy: 0.9000 - 37ms/epoch - 12ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.3647 - val_accuracy: 0.9000 - 39ms/epoch - 13ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.0368 - accuracy: 0.9889 - val_loss: 0.3055 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.0339 - accuracy: 0.9889 - val_loss: 0.2597 - val_accuracy: 0.9667 - 37ms/epoch - 12ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.0680 - accuracy: 0.9778 - val_loss: 0.2310 - val_accuracy: 1.0000 - 37ms/epoch - 12ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.0660 - accuracy: 0.9667 - val_loss: 0.2156 - val_accuracy: 1.0000 - 42ms/epoch - 14ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.0426 - accuracy: 0.9889 - val_loss: 0.1990 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.1318 - accuracy: 0.9556 - val_loss: 0.2010 - val_accuracy: 1.0000 - 38ms/epoch - 13ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.0980 - accuracy: 0.9667 - val_loss: 0.2289 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.0855 - accuracy: 0.9667 - val_loss: 0.2396 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.1103 - accuracy: 0.9556 - val_loss: 0.2531 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.0896 - accuracy: 0.9778 - val_loss: 0.2647 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.0656 - accuracy: 0.9778 - val_loss: 0.2554 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.1190 - accuracy: 0.9333 - val_loss: 0.2475 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.0826 - accuracy: 0.9889 - val_loss: 0.2466 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.0986 - accuracy: 0.9556 - val_loss: 0.2667 - val_accuracy: 0.9000 - 37ms/epoch - 12ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.1163 - accuracy: 0.9556 - val_loss: 0.3291 - val_accuracy: 0.9000 - 37ms/epoch - 12ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.0561 - accuracy: 0.9778 - val_loss: 0.3293 - val_accuracy: 0.9000 - 38ms/epoch - 13ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.0591 - accuracy: 0.9889 - val_loss: 0.2608 - val_accuracy: 0.9000 - 37ms/epoch - 12ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.0357 - accuracy: 0.9889 - val_loss: 0.2032 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.0269 - accuracy: 0.9889 - val_loss: 0.1897 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.0310 - accuracy: 0.9889 - val_loss: 0.1968 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.0361 - accuracy: 0.9889 - val_loss: 0.2114 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.0257 - accuracy: 0.9889 - val_loss: 0.2292 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.0288 - accuracy: 0.9889 - val_loss: 0.2265 - val_accuracy: 0.9333 - 35ms/epoch - 12ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.0886 - accuracy: 0.9667 - val_loss: 0.1973 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9333 - 36ms/epoch - 12ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.1857 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.0286 - accuracy: 0.9778 - val_loss: 0.1792 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.0321 - accuracy: 0.9889 - val_loss: 0.1831 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.0359 - accuracy: 0.9778 - val_loss: 0.2199 - val_accuracy: 0.9000 - 37ms/epoch - 12ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.2998 - val_accuracy: 0.8000 - 38ms/epoch - 13ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.0603 - accuracy: 0.9778 - val_loss: 0.3183 - val_accuracy: 0.8000 - 40ms/epoch - 13ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.2844 - val_accuracy: 0.8333 - 38ms/epoch - 13ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.0662 - accuracy: 0.9556 - val_loss: 0.2291 - val_accuracy: 0.9000 - 42ms/epoch - 14ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.0212 - accuracy: 0.9889 - val_loss: 0.1697 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.0357 - accuracy: 0.9889 - val_loss: 0.1556 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.1089 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9667 - 36ms/epoch - 12ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 0.9667 - 36ms/epoch - 12ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9667 - 36ms/epoch - 12ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9667 - 34ms/epoch - 11ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 0.9667 - 36ms/epoch - 12ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.0464 - accuracy: 0.9778 - val_loss: 0.0948 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.0719 - accuracy: 0.9889 - val_loss: 0.0949 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.0412 - accuracy: 0.9889 - val_loss: 0.0883 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.0663 - accuracy: 0.9889 - val_loss: 0.2380 - val_accuracy: 0.8667 - 40ms/epoch - 13ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.0835 - accuracy: 0.9889 - val_loss: 0.3551 - val_accuracy: 0.8000 - 36ms/epoch - 12ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.1089 - accuracy: 0.9778 - val_loss: 0.3649 - val_accuracy: 0.8000 - 36ms/epoch - 12ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.1088 - accuracy: 0.9444 - val_loss: 0.2011 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.0294 - accuracy: 0.9889 - val_loss: 0.1198 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.3762 - accuracy: 0.9333 - val_loss: 0.0992 - val_accuracy: 0.9667 - 34ms/epoch - 11ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.0543 - accuracy: 0.9778 - val_loss: 0.1211 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.0324 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.0290 - accuracy: 0.9889 - val_loss: 0.1565 - val_accuracy: 0.9333 - 35ms/epoch - 12ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.1277 - accuracy: 0.9556 - val_loss: 0.2041 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.0385 - accuracy: 0.9889 - val_loss: 0.2897 - val_accuracy: 0.8667 - 46ms/epoch - 15ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.0406 - accuracy: 0.9889 - val_loss: 0.3577 - val_accuracy: 0.8333 - 44ms/epoch - 15ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.0536 - accuracy: 0.9889 - val_loss: 0.3754 - val_accuracy: 0.8333 - 45ms/epoch - 15ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.0744 - accuracy: 0.9889 - val_loss: 0.3330 - val_accuracy: 0.8667 - 42ms/epoch - 14ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.2769 - val_accuracy: 0.9000 - 43ms/epoch - 14ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.2209 - val_accuracy: 0.8667 - 45ms/epoch - 15ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.0312 - accuracy: 0.9889 - val_loss: 0.1726 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.0339 - accuracy: 0.9889 - val_loss: 0.1520 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.1755 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.0555 - accuracy: 0.9889 - val_loss: 0.2255 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9000 - 40ms/epoch - 13ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9333 - 132ms/epoch - 44ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.0390 - accuracy: 0.9889 - val_loss: 0.1294 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.1431 - accuracy: 0.9556 - val_loss: 0.1298 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.0283 - accuracy: 0.9889 - val_loss: 0.1515 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.0346 - accuracy: 0.9889 - val_loss: 0.1308 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.0394 - accuracy: 0.9889 - val_loss: 0.1267 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.0188 - accuracy: 0.9889 - val_loss: 0.1333 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.0440 - accuracy: 0.9889 - val_loss: 0.1391 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.0276 - accuracy: 0.9889 - val_loss: 0.1421 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.0791 - accuracy: 0.9778 - val_loss: 0.1252 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.0235 - accuracy: 0.9889 - val_loss: 0.0958 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.0680 - accuracy: 0.9667 - val_loss: 0.0937 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.0254 - accuracy: 0.9889 - val_loss: 0.1097 - val_accuracy: 0.9333 - 36ms/epoch - 12ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.0619 - accuracy: 0.9889 - val_loss: 0.1405 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.0232 - accuracy: 0.9889 - val_loss: 0.1773 - val_accuracy: 0.9000 - 37ms/epoch - 12ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2008 - val_accuracy: 0.9000 - 53ms/epoch - 18ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9000 - 44ms/epoch - 15ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.0974 - accuracy: 0.9778 - val_loss: 0.2076 - val_accuracy: 0.9000 - 39ms/epoch - 13ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9000 - 38ms/epoch - 13ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.0390 - accuracy: 0.9778 - val_loss: 0.2171 - val_accuracy: 0.9000 - 40ms/epoch - 13ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.1151 - accuracy: 0.9667 - val_loss: 0.2045 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.0654 - accuracy: 0.9778 - val_loss: 0.1997 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.2424 - val_accuracy: 0.8667 - 40ms/epoch - 13ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.0798 - accuracy: 0.9667 - val_loss: 0.2879 - val_accuracy: 0.8667 - 38ms/epoch - 13ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.2916 - val_accuracy: 0.8667 - 41ms/epoch - 14ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.0296 - accuracy: 0.9889 - val_loss: 0.2834 - val_accuracy: 0.8667 - 39ms/epoch - 13ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.2718 - val_accuracy: 0.8667 - 40ms/epoch - 13ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.0376 - accuracy: 0.9778 - val_loss: 0.2592 - val_accuracy: 0.8667 - 38ms/epoch - 13ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.0365 - accuracy: 0.9889 - val_loss: 0.2288 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.0407 - accuracy: 0.9889 - val_loss: 0.1837 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.0176 - accuracy: 0.9889 - val_loss: 0.1855 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2381 - val_accuracy: 0.8667 - 38ms/epoch - 13ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.2619 - val_accuracy: 0.9000 - 37ms/epoch - 12ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.0823 - accuracy: 0.9889 - val_loss: 0.2162 - val_accuracy: 0.9000 - 38ms/epoch - 13ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.0182 - accuracy: 0.9889 - val_loss: 0.1280 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.0177 - accuracy: 0.9889 - val_loss: 0.1084 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.0211 - accuracy: 0.9889 - val_loss: 0.1188 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.0481 - accuracy: 0.9889 - val_loss: 0.1364 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.0324 - accuracy: 0.9889 - val_loss: 0.1490 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9333 - 38ms/epoch - 13ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9333 - 37ms/epoch - 12ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.0429 - accuracy: 0.9889 - val_loss: 0.1441 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.0704 - accuracy: 0.9889 - val_loss: 0.1788 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.1731 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.1147 - accuracy: 0.9667 - val_loss: 0.1409 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.0202 - accuracy: 0.9889 - val_loss: 0.1267 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0312 - accuracy: 0.9889 - val_loss: 0.1166 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_' + metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation ' + metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_' + metric])
    plt.show()

# %%
plot_metric(history, 'accuracy')

# %%
plot_metric(history, 'loss')

# %%
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.1828 - accuracy: 0.9667 - 28ms/epoch - 28ms/step
# [0.18278077244758606, 0.9666666388511658]

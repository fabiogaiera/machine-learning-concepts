# %% [markdown]
# ## Batch Normalization
#
# In the rise of deep learning, one of the most important ideas has been an algorithm called batch normalization (also known as batch norm).
#
# Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.
#
# Batch normalization can be implemented during training by calculating the mean and standard deviation of each input variable to a layer per mini-batch and using these statistics to perform the standardization.
#
# The benefits of batch normalization are:
#
# - A deep neural network can be trained faster: Although each training iteration will be slower because of the extra normalization calculation during the forward pass and the additional hyperparameters to train during backpropagation, it should converge much more quickly; thus, training should be faster overall.
#
# - Higher learning rate: Gradient descent generally requires small learning rates for the network to converge. As networks become deeper, gradients become smaller during backpropagation and thus require even more iterations. Using batch normalization allows much higher learning rates, thereby increasing the speed of training.
#
# - Easier to initialize weight: Weight initialization can be difficult, particularly when creating deeper networks. Batch normalization reduces the sensitivity to the initial starting weights.

# %% [markdown]
# ## Batch Normalization implementation

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
# Out:
# 2022-11-10 22:08:48.782612: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-10 22:08:48.880265: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-10 22:08:48.880280: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-10 22:08:48.902403: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-10 22:08:49.338856: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-10 22:08:49.338923: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-10 22:08:49.338942: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ### Loading dataset

# %%
# Load data into a DataFrame
dataset = load_iris()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)

# Append "target" and name it "label"
df['label'] = dataset.target

# Use string label instead
df['label'] = df.label.replace(dict(enumerate(dataset.target_names)))

# %% [markdown]
# ### Exploring dataset

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#     label
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ### Preparing data for TensorFlow

# %%
# Transform label to one-hot encoding
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)

# Drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label_setosa  label_versicolor  label_virginica
# 0             1                 0                0
# 1             1                 0                0
# 2             1                 0                0
# 3             1                 0                0
# 4             1                 0                0

# %%
# Creating X and y

# Convert DataFrame into np array
X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
X = np.asarray(X)

# Convert DataFrame into np array
y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
y = np.asarray(y)

# %%
# Split the data set in a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (112, 4)
# (38, 4)
# (112, 3)
# (38, 3)

# %% [markdown]
# ### Batch normalization

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization

# %%
# Model without batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 37,763
# Trainable params: 37,763
# Non-trainable params: 0
# _________________________________________________________________
# 2022-11-10 22:08:50.323450: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-11-10 22:08:50.323657: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-10 22:08:50.323672: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (fabio-XPS-15-7590): /proc/driver/nvidia/version does not exist
# 2022-11-10 22:08:50.324252: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Model with batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(3, activation='softmax')
]);

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                320
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dense_7 (Dense)             (None, 128)               8320
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_11 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________

# %%
from tensorflow.keras.initializers import RandomNormal, Constant

# Model with a customized batch normalization
model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(
        momentum=0.95, 
        epsilon=0.005,
        beta_initializer=RandomNormal(mean=0.0, stddev=0.05), 
        gamma_initializer=Constant(value=0.9)
    ),
    Dense(3, activation='softmax')
]);

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 64)                320
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_13 (Dense)            (None, 128)               8320
#
#  batch_normalization_6 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_14 (Dense)            (None, 128)               16512
#
#  batch_normalization_7 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_15 (Dense)            (None, 64)                8256
#
#  batch_normalization_8 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  batch_normalization_9 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_17 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 39,555
# Trainable params: 38,659
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# ### Model training

# %%
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 1s - loss: 1.1771 - accuracy: 0.4643 - val_loss: 1.0644 - val_accuracy: 0.4286 - 1s/epoch - 403ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 0.3819 - accuracy: 0.8690 - val_loss: 1.0660 - val_accuracy: 0.6429 - 25ms/epoch - 8ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.2907 - accuracy: 0.9167 - val_loss: 1.0766 - val_accuracy: 0.6429 - 25ms/epoch - 8ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.2219 - accuracy: 0.9524 - val_loss: 1.0953 - val_accuracy: 0.6071 - 25ms/epoch - 8ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.2281 - accuracy: 0.9405 - val_loss: 1.1101 - val_accuracy: 0.5357 - 28ms/epoch - 9ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.1688 - accuracy: 0.9286 - val_loss: 1.1336 - val_accuracy: 0.2143 - 25ms/epoch - 8ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.1964 - accuracy: 0.9524 - val_loss: 1.1456 - val_accuracy: 0.2143 - 27ms/epoch - 9ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 0.1658 - accuracy: 0.9524 - val_loss: 1.1603 - val_accuracy: 0.2143 - 25ms/epoch - 8ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.2055 - accuracy: 0.9405 - val_loss: 1.1867 - val_accuracy: 0.2143 - 25ms/epoch - 8ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.1861 - accuracy: 0.9286 - val_loss: 1.2073 - val_accuracy: 0.2143 - 25ms/epoch - 8ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.1584 - accuracy: 0.9524 - val_loss: 1.2130 - val_accuracy: 0.2143 - 24ms/epoch - 8ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.2169 - accuracy: 0.9524 - val_loss: 1.2156 - val_accuracy: 0.2143 - 25ms/epoch - 8ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.1401 - accuracy: 0.9762 - val_loss: 1.1991 - val_accuracy: 0.2143 - 25ms/epoch - 8ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.1591 - accuracy: 0.9762 - val_loss: 1.1832 - val_accuracy: 0.2143 - 24ms/epoch - 8ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.1368 - accuracy: 0.9762 - val_loss: 1.1607 - val_accuracy: 0.2143 - 24ms/epoch - 8ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.1779 - accuracy: 0.9524 - val_loss: 1.1351 - val_accuracy: 0.2143 - 23ms/epoch - 8ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.1565 - accuracy: 0.9524 - val_loss: 1.1044 - val_accuracy: 0.2143 - 29ms/epoch - 10ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.1505 - accuracy: 0.9643 - val_loss: 1.0853 - val_accuracy: 0.2143 - 26ms/epoch - 9ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.1382 - accuracy: 0.9762 - val_loss: 1.0647 - val_accuracy: 0.3214 - 25ms/epoch - 8ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.1079 - accuracy: 0.9762 - val_loss: 1.0379 - val_accuracy: 0.5357 - 27ms/epoch - 9ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.1002 - accuracy: 0.9881 - val_loss: 1.0245 - val_accuracy: 0.6071 - 23ms/epoch - 8ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.1100 - accuracy: 0.9762 - val_loss: 1.0089 - val_accuracy: 0.6071 - 25ms/epoch - 8ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.2027 - accuracy: 0.9405 - val_loss: 0.9917 - val_accuracy: 0.6429 - 26ms/epoch - 9ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.1050 - accuracy: 0.9643 - val_loss: 0.9792 - val_accuracy: 0.6429 - 24ms/epoch - 8ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.1459 - accuracy: 0.9643 - val_loss: 0.9676 - val_accuracy: 0.6429 - 25ms/epoch - 8ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.2231 - accuracy: 0.9286 - val_loss: 0.9435 - val_accuracy: 0.6429 - 23ms/epoch - 8ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.1042 - accuracy: 0.9762 - val_loss: 0.9304 - val_accuracy: 0.6429 - 25ms/epoch - 8ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.0946 - accuracy: 0.9762 - val_loss: 0.9221 - val_accuracy: 0.6429 - 23ms/epoch - 8ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.1465 - accuracy: 0.9405 - val_loss: 0.9250 - val_accuracy: 0.6071 - 27ms/epoch - 9ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.1545 - accuracy: 0.9762 - val_loss: 0.9205 - val_accuracy: 0.6071 - 23ms/epoch - 8ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.1499 - accuracy: 0.9762 - val_loss: 0.9102 - val_accuracy: 0.6071 - 25ms/epoch - 8ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.2073 - accuracy: 0.9524 - val_loss: 0.9028 - val_accuracy: 0.6071 - 25ms/epoch - 8ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.1524 - accuracy: 0.9524 - val_loss: 0.8861 - val_accuracy: 0.6071 - 24ms/epoch - 8ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.1378 - accuracy: 0.9405 - val_loss: 0.8650 - val_accuracy: 0.6429 - 25ms/epoch - 8ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.1420 - accuracy: 0.9405 - val_loss: 0.8345 - val_accuracy: 0.8571 - 25ms/epoch - 8ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.1860 - accuracy: 0.9405 - val_loss: 0.8186 - val_accuracy: 0.8929 - 26ms/epoch - 9ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.1313 - accuracy: 0.9643 - val_loss: 0.8267 - val_accuracy: 0.8929 - 24ms/epoch - 8ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.1345 - accuracy: 0.9762 - val_loss: 0.8144 - val_accuracy: 0.9643 - 26ms/epoch - 9ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.1147 - accuracy: 0.9643 - val_loss: 0.8093 - val_accuracy: 0.9643 - 26ms/epoch - 9ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.1360 - accuracy: 0.9524 - val_loss: 0.7851 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.1373 - accuracy: 0.9524 - val_loss: 0.7657 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.1246 - accuracy: 0.9643 - val_loss: 0.7545 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.1555 - accuracy: 0.9643 - val_loss: 0.7632 - val_accuracy: 1.0000 - 26ms/epoch - 9ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.2171 - accuracy: 0.9524 - val_loss: 0.7853 - val_accuracy: 1.0000 - 26ms/epoch - 9ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.1980 - accuracy: 0.9405 - val_loss: 0.7899 - val_accuracy: 0.9286 - 24ms/epoch - 8ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.1563 - accuracy: 0.9286 - val_loss: 0.7846 - val_accuracy: 0.9643 - 25ms/epoch - 8ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.1068 - accuracy: 0.9881 - val_loss: 0.7591 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.1285 - accuracy: 0.9881 - val_loss: 0.7436 - val_accuracy: 0.9643 - 25ms/epoch - 8ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.0983 - accuracy: 0.9762 - val_loss: 0.7449 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.1337 - accuracy: 0.9524 - val_loss: 0.7316 - val_accuracy: 1.0000 - 26ms/epoch - 9ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.0941 - accuracy: 0.9762 - val_loss: 0.6968 - val_accuracy: 1.0000 - 26ms/epoch - 9ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.1238 - accuracy: 0.9643 - val_loss: 0.6497 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.0931 - accuracy: 0.9762 - val_loss: 0.6023 - val_accuracy: 1.0000 - 28ms/epoch - 9ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.1279 - accuracy: 0.9643 - val_loss: 0.5569 - val_accuracy: 1.0000 - 27ms/epoch - 9ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.0848 - accuracy: 0.9762 - val_loss: 0.5339 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.1221 - accuracy: 0.9643 - val_loss: 0.5205 - val_accuracy: 1.0000 - 21ms/epoch - 7ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.0678 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.0767 - accuracy: 0.9881 - val_loss: 0.5035 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.0869 - accuracy: 0.9762 - val_loss: 0.4773 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.0812 - accuracy: 0.9762 - val_loss: 0.4526 - val_accuracy: 1.0000 - 26ms/epoch - 9ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.1476 - accuracy: 0.9643 - val_loss: 0.4232 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.1181 - accuracy: 0.9762 - val_loss: 0.4329 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.0667 - accuracy: 0.9881 - val_loss: 0.4507 - val_accuracy: 0.9286 - 25ms/epoch - 8ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.1298 - accuracy: 0.9643 - val_loss: 0.4572 - val_accuracy: 0.9286 - 25ms/epoch - 8ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.0745 - accuracy: 0.9762 - val_loss: 0.4579 - val_accuracy: 0.9286 - 29ms/epoch - 10ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.1313 - accuracy: 0.9524 - val_loss: 0.4612 - val_accuracy: 0.9286 - 23ms/epoch - 8ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.0856 - accuracy: 0.9643 - val_loss: 0.4461 - val_accuracy: 0.9286 - 24ms/epoch - 8ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.0817 - accuracy: 0.9643 - val_loss: 0.4217 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.0928 - accuracy: 0.9762 - val_loss: 0.4046 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.0736 - accuracy: 0.9762 - val_loss: 0.3989 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.0687 - accuracy: 1.0000 - val_loss: 0.3876 - val_accuracy: 1.0000 - 26ms/epoch - 9ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.0795 - accuracy: 0.9762 - val_loss: 0.3864 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.0668 - accuracy: 0.9762 - val_loss: 0.3876 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.0712 - accuracy: 0.9762 - val_loss: 0.3752 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.1293 - accuracy: 0.9524 - val_loss: 0.3750 - val_accuracy: 1.0000 - 26ms/epoch - 9ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.0837 - accuracy: 0.9881 - val_loss: 0.3727 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.1287 - accuracy: 0.9643 - val_loss: 0.3513 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.1001 - accuracy: 0.9643 - val_loss: 0.3457 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.0966 - accuracy: 0.9762 - val_loss: 0.3507 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.1201 - accuracy: 0.9524 - val_loss: 0.3442 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.0731 - accuracy: 0.9881 - val_loss: 0.3726 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.1046 - accuracy: 0.9762 - val_loss: 0.3967 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.0760 - accuracy: 0.9762 - val_loss: 0.4280 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.1371 - accuracy: 0.9524 - val_loss: 0.4332 - val_accuracy: 0.9643 - 22ms/epoch - 7ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.0634 - accuracy: 1.0000 - val_loss: 0.4176 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.0930 - accuracy: 0.9762 - val_loss: 0.3886 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.0771 - accuracy: 0.9643 - val_loss: 0.3609 - val_accuracy: 0.9643 - 26ms/epoch - 9ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.0933 - accuracy: 0.9762 - val_loss: 0.3402 - val_accuracy: 0.9643 - 25ms/epoch - 8ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.0842 - accuracy: 0.9762 - val_loss: 0.2933 - val_accuracy: 0.9643 - 22ms/epoch - 7ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.1235 - accuracy: 0.9524 - val_loss: 0.2330 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.1557 - accuracy: 0.9643 - val_loss: 0.1969 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.0563 - accuracy: 0.9762 - val_loss: 0.1803 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.1441 - accuracy: 0.9643 - val_loss: 0.1721 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.0407 - accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.0547 - accuracy: 0.9762 - val_loss: 0.1717 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.1637 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.1537 - accuracy: 0.9643 - val_loss: 0.1539 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.0496 - accuracy: 0.9881 - val_loss: 0.1409 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.1601 - accuracy: 0.9524 - val_loss: 0.1375 - val_accuracy: 1.0000 - 26ms/epoch - 9ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.0690 - accuracy: 0.9881 - val_loss: 0.1554 - val_accuracy: 1.0000 - 21ms/epoch - 7ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.1000 - accuracy: 0.9643 - val_loss: 0.1668 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.0751 - accuracy: 1.0000 - val_loss: 0.1718 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.1262 - accuracy: 0.9405 - val_loss: 0.1860 - val_accuracy: 1.0000 - 26ms/epoch - 9ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.0766 - accuracy: 0.9762 - val_loss: 0.1978 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.0726 - accuracy: 0.9762 - val_loss: 0.2047 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.0861 - accuracy: 0.9881 - val_loss: 0.1890 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.0763 - accuracy: 0.9881 - val_loss: 0.1903 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.0919 - accuracy: 0.9643 - val_loss: 0.2065 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.0842 - accuracy: 0.9643 - val_loss: 0.2172 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.0435 - accuracy: 0.9881 - val_loss: 0.2169 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.0644 - accuracy: 0.9881 - val_loss: 0.2075 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.1315 - accuracy: 0.9524 - val_loss: 0.2121 - val_accuracy: 0.9643 - 22ms/epoch - 7ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.0517 - accuracy: 0.9881 - val_loss: 0.2621 - val_accuracy: 0.8929 - 23ms/epoch - 8ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.0480 - accuracy: 0.9881 - val_loss: 0.2897 - val_accuracy: 0.8571 - 23ms/epoch - 8ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.0717 - accuracy: 0.9881 - val_loss: 0.2977 - val_accuracy: 0.8571 - 22ms/epoch - 7ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.0510 - accuracy: 1.0000 - val_loss: 0.3050 - val_accuracy: 0.8571 - 22ms/epoch - 7ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.1189 - accuracy: 0.9643 - val_loss: 0.2959 - val_accuracy: 0.8571 - 24ms/epoch - 8ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.0591 - accuracy: 1.0000 - val_loss: 0.2769 - val_accuracy: 0.8571 - 23ms/epoch - 8ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.1212 - accuracy: 0.9405 - val_loss: 0.2577 - val_accuracy: 0.8214 - 22ms/epoch - 7ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.0945 - accuracy: 0.9643 - val_loss: 0.2310 - val_accuracy: 0.8929 - 22ms/epoch - 7ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.1292 - accuracy: 0.9643 - val_loss: 0.1952 - val_accuracy: 0.9286 - 24ms/epoch - 8ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.2182 - accuracy: 0.8929 - val_loss: 0.1681 - val_accuracy: 0.9286 - 23ms/epoch - 8ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.1352 - accuracy: 0.9643 - val_loss: 0.1451 - val_accuracy: 0.9286 - 25ms/epoch - 8ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.0570 - accuracy: 0.9881 - val_loss: 0.1322 - val_accuracy: 0.9643 - 22ms/epoch - 7ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.0995 - accuracy: 0.9762 - val_loss: 0.1180 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.1161 - accuracy: 0.9524 - val_loss: 0.1114 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.0539 - accuracy: 0.9881 - val_loss: 0.1123 - val_accuracy: 0.9643 - 22ms/epoch - 7ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.1314 - accuracy: 0.9643 - val_loss: 0.1187 - val_accuracy: 0.9643 - 22ms/epoch - 7ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.0596 - accuracy: 0.9881 - val_loss: 0.1311 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.0697 - accuracy: 0.9881 - val_loss: 0.1349 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.0815 - accuracy: 0.9762 - val_loss: 0.1350 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.0592 - accuracy: 0.9881 - val_loss: 0.1303 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.0567 - accuracy: 0.9881 - val_loss: 0.1305 - val_accuracy: 1.0000 - 26ms/epoch - 9ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.0643 - accuracy: 0.9881 - val_loss: 0.1355 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.0923 - accuracy: 0.9643 - val_loss: 0.1344 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.0647 - accuracy: 0.9762 - val_loss: 0.1323 - val_accuracy: 1.0000 - 21ms/epoch - 7ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.0658 - accuracy: 0.9881 - val_loss: 0.1248 - val_accuracy: 0.9643 - 27ms/epoch - 9ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.0768 - accuracy: 0.9643 - val_loss: 0.1181 - val_accuracy: 0.9643 - 21ms/epoch - 7ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.0409 - accuracy: 1.0000 - val_loss: 0.1077 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.0766 - accuracy: 0.9881 - val_loss: 0.1094 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.0836 - accuracy: 0.9881 - val_loss: 0.1380 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.1275 - accuracy: 0.9643 - val_loss: 0.1768 - val_accuracy: 0.9286 - 23ms/epoch - 8ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.0647 - accuracy: 0.9762 - val_loss: 0.2257 - val_accuracy: 0.9286 - 24ms/epoch - 8ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.1150 - accuracy: 0.9881 - val_loss: 0.2591 - val_accuracy: 0.8929 - 30ms/epoch - 10ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.1060 - accuracy: 0.9643 - val_loss: 0.2788 - val_accuracy: 0.8214 - 30ms/epoch - 10ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.1293 - accuracy: 0.9643 - val_loss: 0.2864 - val_accuracy: 0.8214 - 23ms/epoch - 8ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.1183 - accuracy: 0.9762 - val_loss: 0.2958 - val_accuracy: 0.8214 - 24ms/epoch - 8ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.1060 - accuracy: 0.9881 - val_loss: 0.2937 - val_accuracy: 0.8214 - 24ms/epoch - 8ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.1338 - accuracy: 0.9524 - val_loss: 0.2886 - val_accuracy: 0.8214 - 27ms/epoch - 9ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.1205 - accuracy: 0.9881 - val_loss: 0.2644 - val_accuracy: 0.8571 - 23ms/epoch - 8ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.0955 - accuracy: 0.9881 - val_loss: 0.2368 - val_accuracy: 0.8929 - 24ms/epoch - 8ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.0987 - accuracy: 0.9643 - val_loss: 0.1956 - val_accuracy: 0.9286 - 25ms/epoch - 8ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.1085 - accuracy: 0.9524 - val_loss: 0.1712 - val_accuracy: 0.9286 - 23ms/epoch - 8ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.0736 - accuracy: 0.9881 - val_loss: 0.1642 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.0777 - accuracy: 0.9762 - val_loss: 0.1567 - val_accuracy: 0.9643 - 25ms/epoch - 8ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.1033 - accuracy: 0.9762 - val_loss: 0.1529 - val_accuracy: 0.9643 - 25ms/epoch - 8ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.0745 - accuracy: 0.9881 - val_loss: 0.1521 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.0874 - accuracy: 0.9643 - val_loss: 0.1432 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.1031 - accuracy: 0.9762 - val_loss: 0.1437 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.0871 - accuracy: 0.9643 - val_loss: 0.1285 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.0541 - accuracy: 0.9881 - val_loss: 0.1117 - val_accuracy: 0.9643 - 26ms/epoch - 9ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.0880 - accuracy: 0.9762 - val_loss: 0.0918 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.0416 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 0.9643 - 22ms/epoch - 7ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.0484 - accuracy: 0.9881 - val_loss: 0.0976 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.0580 - accuracy: 0.9762 - val_loss: 0.1008 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.0433 - accuracy: 0.9881 - val_loss: 0.1085 - val_accuracy: 0.9643 - 22ms/epoch - 7ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.0531 - accuracy: 0.9762 - val_loss: 0.1090 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.0632 - accuracy: 0.9762 - val_loss: 0.0839 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.0511 - accuracy: 0.9881 - val_loss: 0.0663 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.0603 - accuracy: 0.9762 - val_loss: 0.0625 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.1522 - accuracy: 0.9643 - val_loss: 0.0638 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.0632 - accuracy: 0.9881 - val_loss: 0.0739 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.0717 - accuracy: 0.9643 - val_loss: 0.0892 - val_accuracy: 1.0000 - 25ms/epoch - 8ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.1061 - accuracy: 0.9762 - val_loss: 0.1010 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.0489 - accuracy: 0.9881 - val_loss: 0.1192 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.1731 - accuracy: 0.9524 - val_loss: 0.1351 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.0598 - accuracy: 0.9881 - val_loss: 0.1645 - val_accuracy: 0.9286 - 24ms/epoch - 8ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.0516 - accuracy: 0.9881 - val_loss: 0.1885 - val_accuracy: 0.9286 - 23ms/epoch - 8ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.1112 - accuracy: 0.9643 - val_loss: 0.2176 - val_accuracy: 0.8929 - 24ms/epoch - 8ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.0597 - accuracy: 0.9881 - val_loss: 0.2489 - val_accuracy: 0.8929 - 26ms/epoch - 9ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.0928 - accuracy: 0.9643 - val_loss: 0.2503 - val_accuracy: 0.8571 - 22ms/epoch - 7ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.0727 - accuracy: 0.9881 - val_loss: 0.2349 - val_accuracy: 0.8929 - 23ms/epoch - 8ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.0651 - accuracy: 0.9762 - val_loss: 0.2162 - val_accuracy: 0.9286 - 24ms/epoch - 8ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.0689 - accuracy: 0.9881 - val_loss: 0.2004 - val_accuracy: 0.9286 - 23ms/epoch - 8ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.0517 - accuracy: 1.0000 - val_loss: 0.1885 - val_accuracy: 0.9286 - 23ms/epoch - 8ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.0722 - accuracy: 1.0000 - val_loss: 0.1824 - val_accuracy: 0.9286 - 24ms/epoch - 8ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.1118 - accuracy: 0.9524 - val_loss: 0.1641 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.0484 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9643 - 23ms/epoch - 8ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.1487 - accuracy: 0.9524 - val_loss: 0.0695 - val_accuracy: 0.9643 - 24ms/epoch - 8ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.0630 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0544 - accuracy: 0.9881 - val_loss: 0.0376 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.0604 - accuracy: 0.9762 - val_loss: 0.0437 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0600 - accuracy: 0.9762 - val_loss: 0.0443 - val_accuracy: 1.0000 - 22ms/epoch - 7ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0820 - accuracy: 0.9643 - val_loss: 0.0396 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.1089 - accuracy: 0.9643 - val_loss: 0.0309 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0424 - accuracy: 0.9881 - val_loss: 0.0259 - val_accuracy: 1.0000 - 23ms/epoch - 8ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.0636 - accuracy: 0.9762 - val_loss: 0.0240 - val_accuracy: 1.0000 - 24ms/epoch - 8ms/step

# %% [markdown]
# ### Model evaluation
#
# Finally, we plot training and validation loss and accuracy to observe how the accuracy of our model improves over time.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_' + metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation ' + metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_' + metric])
    plt.show()

# %%
plot_metric(history, 'accuracy')

# %%
plot_metric(history, 'loss')

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 2/2 - 0s - loss: 0.0877 - accuracy: 0.9737 - 18ms/epoch - 9ms/step
# [0.08765500038862228, 0.9736841917037964]
